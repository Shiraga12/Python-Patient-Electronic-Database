# %%
from patient import Patient as PD
from patient import Billing as BD
import pandas as pd
import datetime
my_birthday = datetime.date(2001, 4, 29)

# %%
PATIENT = []
PATIENT.append(PD("Gastion","Leger",7553,1,8,1949,3,30,2023,"Dr. Capello","M"))
PATIENT.append(PD("Romain","Pierre",7539,1,30,1972,2,12,2023,"Dr. Capello","M"))
PATIENT.append(PD("Jinnoux","Fils",7528,3,6,1987,2,1,2023,"Dr. Capello","M"))
PATIENT.append(PD("Alnazir","Blackman",7541,1,26,1999,2,22,2023,"Dr. Capello","M"))
PATIENT.append(PD("Marcelin","Cherilus",7540,3,5,1973,2,19,2023,"Dr. Capello","F"))
PATIENT.append(PD("Jacquez","Edyson",7496,9,19,2001,4,8,2022,"Dr. Capello","M"))
PATIENT.append(PD("Jordan","Joseph",7550,6,7,1996,3,19,2023,"Dr. Capello","M"))
PATIENT.append(PD("Harvey","Lamont",None,-1,-1,-1,3,17,2023,None,"M"))
PATIENT.append(PD("Fredrick","Mensah-Bonsu",7551,9,30,1975,3,24,2023,"Dr. Capello","M"))
PATIENT.append(PD("Robert","Kirkland",5597,1,4,1960,9,14,2010,"J. Fieldman, DPM","M"))
PATIENT.append(PD("Kerline","Gelin",7533,8,3,1972,2,3,2023,"Dr. John King","F"))
PATIENT.append(PD("Annecia","Etienne",7542,5,8,1977,2,25,2023,"Dr. Capello","F"))
PATIENT.append(PD("Vinci","Etienne",7536,10,10,1964,2,9,2023,"Dr. Capello","M"))
PATIENT.append(PD("Clyvens","Bruneus",7526,12,26,1992,2,1,2023,"Dr. Capello","M"))
PATIENT.append(PD("Hollychard","Massillon",7534,5,26,2003,2,3,2023,"Dr. Capello","F"))
PATIENT.append(PD("Dwayne","Mackey",7506,9,30,1985,7,29,2022,"Dr. Capello","M"))
PATIENT.append(PD("Morales","Thomas",None,10,14,1993,3,30,2023,None,"M"))
PATIENT.append(PD("Hams","Simeon",7548,1,11,1991,3,12,2023,"Dr. Capello","M"))
PATIENT.append(PD("Isioma","Enyioko",5227,3,5,1982,12,9,2008,"Dr. David Richmond","F"))
PATIENT.append(PD("Janene","Feijo",5226,7,2,1987,12,5,2008,"Natasha Fuksina, M.D.","F"))
PATIENT.append(PD("Massillon","Jean",7531,3,11,1965,2,2,2023,"Dr. Capello","M"))
PATIENT.append(PD("Dwayne","Mackey",7535,9,30,1985,2,3,2023,"Dr. Capello","M"))
PATIENT.append(PD("Paul","Jean",None,9,16,1991,5,15,2023,None,"M"))
PATIENT.append(PD("Michael","Martinez",7036,5,5,1992,9,14,2018,"Dr. Capello","M"))
PATIENT.append(PD("Emanuel","Magdi",7299,11,5,1961,2,7,2020,"Dr. Capello","M"))
PATIENT.append(PD("Jade","Beauport",7544,2,17,1987,3,9,2023,"Dr. Capello","F"))
PATIENT.append(PD("Tyietha","Burnett",7545,12,2,1976,3,9,2023,"Dr. Capello","F"))
PATIENT.append(PD("Jimmy","Janvier",7537,10,6,1980,2,10,2023,"Dr. Capello","M"))
PATIENT.append(PD("Danny","Mayo",7559,5,23,1965,5,5,2023,"Dr. Capello","M"))
PATIENT.append(PD("Jasmine","Vital",7554,4,27,2006,4,7,2023,"Dr. Capello","F"))
PATIENT.append(PD("Shadae","Johnson",None,7,14,1989,4,27,2023,None,"F"))
PATIENT.append(PD("Shannon","Chisolm",7543,6,15,1967,3,6,2023,"Dr. Capello","F"))
PATIENT.append(PD("Faakhir","Abdul-Azeez",7532,8,1,1956,2,2,2023,"Dr. Capello","M"))
PATIENT.append(PD("Enel","Pierre",7467,6,5,1990,10,23,2021,"Dr. Kirk","M"))
PATIENT.append(PD("Jean Baptiste","Olondieu",7468,7,26,1961,10,23,2021,"Dr. Kirk","M"))
PATIENT.append(PD("Leonel","Rosales",7474,6,28,1970,12,1,2021,"Dr. Nicholas Rizzitello","M"))
PATIENT.append(PD("Sylvia","Brown",7476,8,24,1958,12,8,2021,"Dr. Nicholas Rizzitello","F"))
PATIENT.append(PD("Luci","Calle",5223,12,26,1969,11,29,2008,"Andrew Sokol, D.C.","F"))
PATIENT.append(PD("Manuel","Calle",5224,11,21,1948,11,29,2008,"Andrew Sokol, D.C.","M"))
PATIENT.append(PD("Frances","Jackson",5222,1,17,1961,11,28,2008,"Natasha Fuksina, M.D.","F"))
PATIENT.append(PD("Jean","Polycarpe",5221,8,5,1969,11,24,2008,"Gardey Vastey, D.C.","M"))
PATIENT.append(PD("Shekierra","Whitfield",5219,11,18,1976,11,20,2008,"Andrew Sokol, D.C.","F"))
PATIENT.append(PD("Henry","Moore",5218,2,2,1961,11,18,2008,"Natasha Fuksina, M.D.","M"))
PATIENT.append(PD("Brent","Reynolds",5217,2,17,1960,11,17,2008,"Andrew Sokol, D.C.","M"))
PATIENT.append(PD("Daniel","Tolem",5216,5,18,1960,11,14,2008,"Gardey Vastey, D.C.","M"))
PATIENT.append(PD("Ketia","Meus",5214,7,16,1964,11,11,2008,"Gardey Vastey, D.C.","F"))
PATIENT.append(PD("Frances","Portlock",5215,2,14,1956,11,11,2008,"Natasha Fuksina, M.D.","F"))
PATIENT.append(PD("Etide","Evra",5211,3,3,1981,11,10,2008,"Gardey Vastey, D.C.","F"))
PATIENT.append(PD("Tyshona","Curry",7561,12,12,1985,5,15,2023,"Dr. Capello","F"))

# %%
PATIENT_DF = pd.DataFrame(columns=["First Name","Last Name", "ID", "Date of Birth", "Date of Service", "Physician","Gender","Age","Current Age"])
for i in range(len(PATIENT)):
    PATIENT_DF.loc[i+1,"First Name"] = PATIENT[i].getFirstName()
    PATIENT_DF.loc[i+1,"Last Name"] = PATIENT[i].getLastName()
    PATIENT_DF.loc[i+1,"ID"] = PATIENT[i].getID()
    PATIENT_DF.loc[i+1,"Date of Birth"] = PATIENT[i].getDOB_Full()
    PATIENT_DF.loc[i+1,"Date of Service"] = PATIENT[i].getDOS_Full()
    PATIENT_DF.loc[i+1,"Physician"] = PATIENT[i].getPhysician()
    PATIENT_DF.loc[i+1,"Gender"] = PATIENT[i].getGender()
    PATIENT_DF.loc[i+1,"Age"] = PATIENT[i].getAge()
    PATIENT_DF.loc[i+1,"Current Age"] = PATIENT[i].getCurrentAge()
PATIENT_DF.to_excel("Patients.xlsx", index=False)

# %%
PATIENT_DF.sort_values("ID")
# Out:
#        First Name     Last Name    ID Date of Birth Date of Service  \
# 48          Etide          Evra  5211    03/03/1981      11/10/2008
# 46          Ketia          Meus  5214    07/16/1964      11/11/2008
# 47        Frances      Portlock  5215    02/14/1956      11/11/2008
# 45         Daniel         Tolem  5216    05/18/1960      11/14/2008
# 44          Brent      Reynolds  5217    02/17/1960      11/17/2008
# 43          Henry         Moore  5218    02/02/1961      11/18/2008
# 42      Shekierra     Whitfield  5219    11/18/1976      11/20/2008
# 41           Jean     Polycarpe  5221    08/05/1969      11/24/2008
# 40        Frances       Jackson  5222    01/17/1961      11/28/2008
# 38           Luci         Calle  5223    12/26/1969      11/29/2008
# 39         Manuel         Calle  5224    11/21/1948      11/29/2008
# 20         Janene         Feijo  5226    07/02/1987      12/05/2008
# 19         Isioma       Enyioko  5227    03/05/1982      12/09/2008
# ...

# %%
PATIENT_DF
# Out:
#        First Name     Last Name    ID Date of Birth Date of Service  \
# 1         Gastion         Leger  7553    01/08/1949      03/30/2023
# 2          Romain        Pierre  7539    01/30/1972      02/12/2023
# 3         Jinnoux          Fils  7528    03/06/1987      02/01/2023
# 4         Alnazir      Blackman  7541    01/26/1999      02/22/2023
# 5        Marcelin      Cherilus  7540    03/05/1973      02/19/2023
# 6         Jacquez        Edyson  7496    09/19/2001      04/08/2022
# 7          Jordan        Joseph  7550    06/07/1996      03/19/2023
# 8          Harvey        Lamont  None          None      03/17/2023
# 9        Fredrick  Mensah-Bonsu  7551    09/30/1975      03/24/2023
# 10         Robert      Kirkland  5597    01/04/1960      09/14/2010
# 11        Kerline         Gelin  7533    08/03/1972      02/03/2023
# 12        Annecia       Etienne  7542    05/08/1977      02/25/2023
# 13          Vinci       Etienne  7536    10/10/1964      02/09/2023
# ...

# %%
FEMALE_PATIENT_DF = PATIENT_DF[PATIENT_DF["Gender"] == "F"]
MALE_PATIENT_DF = PATIENT_DF[PATIENT_DF["Gender"] == "M"]

# %%
FEMALE_PATIENT_DF.to_excel("FemalePatients.xlsx", index=False)

# %%
MALE_PATIENT_DF.to_excel("MalePatients.xlsx", index=False)

# %%
BILLING = []
BILLING.append(BD("Dante Mercurio","Endo Surgi Center", "Dr. Adeoti", "Internal Hameroids",4,22,2023,45378))

# %%
BILLING_DF = pd.DataFrame()
for i in range(len(BILLING)):
    BILLING_DF.loc[i+1,"Name"] = BILLING[i].getName()
    BILLING_DF.loc[i+1,"Hospital"] = BILLING[i].getHospital()
    BILLING_DF.loc[i+1,"Doctor"] = BILLING[i].getDoctor()
    BILLING_DF.loc[i+1,"Diagnosis"] = BILLING[i].getDiagnosis()
    BILLING_DF.loc[i+1,"Month"] = BILLING[i].getMonth()
    BILLING_DF.loc[i+1,"Day"] = BILLING[i].getDay()
    BILLING_DF.loc[i+1,"Year"] = BILLING[i].getYear()
    BILLING_DF.loc[i+1,"Procedure"] = BILLING[i].getProcedure()
BILLING_DF = BILLING_DF.astype({'Month':'int'})
BILLING_DF = BILLING_DF.astype({'Day':'int'})
BILLING_DF = BILLING_DF.astype({'Year':'int'})
BILLING_DF = BILLING_DF.astype({'Procedure':'int'})
BILLING_DF
# Out:
#              Name           Hospital      Doctor           Diagnosis  Month  \
# 1  Dante Mercurio  Endo Surgi Center  Dr. Adeoti  Internal Hameroids      4
#
#    Day  Year  Procedure
# 1   22  2023      45378
